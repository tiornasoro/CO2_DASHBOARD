# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3767956.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3783940.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3800954.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3818038.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 47410     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 47411     Zimbabwe  2019      ZWE  15354606.0           NaN       0.473
# 47412     Zimbabwe  2020      ZWE  15669663.0           NaN       0.496
# 47413     Zimbabwe  2021      ZWE  15993525.0           NaN       0.531
# 47414     Zimbabwe  2022      ZWE  16320539.0           NaN       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN     NaN             NaN              NaN  ...
# 1                        NaN     NaN             NaN              NaN  ...
# 2                        NaN     NaN             NaN              NaN  ...
# 3                        NaN     NaN             NaN              NaN  ...
# 4                        NaN     NaN             NaN              NaN  ...
# ...                      ...     ...             ...              ...  ...
# 47410                  0.037  10.715           1.419           15.265  ...
# 47411                  0.031   9.775          -0.939           -8.765  ...
# 47412                  0.032   7.850          -1.926          -19.700  ...
# 47413                  0.033   8.396           0.547            6.962  ...
# 47414                  0.033   8.856           0.460            5.477  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                         NaN                                   NaN
# 1                         NaN                                 0.157
# 2                         NaN                                 0.156
# 3                         NaN                                 0.156
# 4                         NaN                                 0.155
# ...                       ...                                   ...
# 47410                     NaN                                 0.114
# 47411                     NaN                                 0.113
# 47412                     NaN                                 0.112
# 47413                     NaN                                 0.110
# 47414                     NaN                                 0.110
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                              NaN                          NaN
# 1                            0.000                        0.000
# 2                            0.000                        0.000
# 3                            0.000                        0.000
# 4                            0.000                        0.000
# ...                            ...                          ...
# 47410                        0.001                        0.001
# 47411                        0.001                        0.001
# 47412                        0.001                        0.001
# 47413                        0.001                        0.001
# 47414                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                              NaN                          NaN        NaN
# 1                            0.000                          0.0        NaN
# 2                            0.000                          0.0        NaN
# 3                            0.000                          0.0        NaN
# 4                            0.000                          0.0        NaN
# ...                            ...                          ...        ...
# 47410                        0.002                          0.0     116.76
# 47411                        0.002                          0.0     116.03
# 47412                        0.002                          0.0     113.20
# 47413                        0.002                          0.0        NaN
# 47414                        0.002                          0.0        NaN
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                           NaN        NaN              NaN
# 1                           NaN        NaN              NaN
# 2                           NaN        NaN              NaN
# 3                           NaN        NaN              NaN
# 4                           NaN        NaN              NaN
# ...                         ...        ...              ...
# 47410                     29.37     -0.088           -0.825
# 47411                     28.70      0.143            1.463
# 47412                     25.99      0.818           10.421
# 47413                       NaN      1.088           12.956
# 47414                       NaN        NaN              NaN
#
# [47415 rows x 79 columns]

# %% [markdown]
# Data preprocessing

# %%
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %%
idf= df.interactive()

# %% [markdown]
# CO2 emission over time by continent

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)

# %% [markdown]
# Radio buttons for CO2 meazsures

# %%
yaxis_co2=pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['co2','co2_per_capita'],
             button_type='success'
             )

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']
co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='725b1049-cafd-4a92-9bbf-0a615e6cbdb6'>
#   <div id="a29cd954-6149-40a6-b950-84b3dca10553" data-root-id="725b1049-cafd-4a92-9bbf-0a615e6cbdb6" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"04d696ce-8ed3-4ce1-b322-c985abc09813":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"725b1049-cafd-4a92-9bbf-0a615e6cbdb6","attributes":{"name":"Row03914","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"2295a5ce-a2b3-4b71-ae67-b7d14a9b558b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a3e7ae0f-a924-4098-9903-5d5da7e6b5f1","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1fe4060b-72c9-4037-a5b6-fdb4f90d9115","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"050a197e-d586-4acd-9266-d3f4175375a3","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"dd52a493-94ff-4cb8-9363-ab2b8fe3126c","attributes":{"name":"Column03911","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2295a5ce-a2b3-4b71-ae67-b7d14a9b558b"},{"id":"a3e7ae0f-a924-4098-9903-5d5da7e6b5f1"},{"id":"1fe4060b-72c9-4037-a5b6-fdb4f90d9115"},{"id":"050a197e-d586-4acd-9266-d3f4175375a3"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"e29e7bdb-33c7-4df7-a9d5-3199389772b3","attributes":{"name":"Column03881","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2295a5ce-a2b3-4b71-ae67-b7d14a9b558b"},{"id":"a3e7ae0f-a924-4098-9903-5d5da7e6b5f1"},{"id":"1fe4060b-72c9-4037-a5b6-fdb4f90d9115"},{"id":"050a197e-d586-4acd-9266-d3f4175375a3"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"198a0958-3e59-4706-bd9f-901c1c087430","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2295a5ce-a2b3-4b71-ae67-b7d14a9b558b"},{"id":"1fe4060b-72c9-4037-a5b6-fdb4f90d9115"},{"id":"050a197e-d586-4acd-9266-d3f4175375a3"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1850,"step":5}},{"type":"object","name":"RadioButtonGroup","id":"a1b07be4-d92a-427c-b68c-cdac11c25ad6","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2295a5ce-a2b3-4b71-ae67-b7d14a9b558b"},{"type":"object","name":"ImportedStyleSheet","id":"ef89c370-f6ae-4db6-8243-d1a002dfc4e0","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"1fe4060b-72c9-4037-a5b6-fdb4f90d9115"},{"id":"050a197e-d586-4acd-9266-d3f4175375a3"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"66b92b3e-0490-4065-bc53-e1b780814523","attributes":{"name":"Column03896","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":
style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7654a4c4-9edd-43b0-bade-a756f075a075":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"92d8dd60-f1b7-4c8e-a676-9f25f172d997","attributes":{"name":"Row23621","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"0595ef8a-6168-42ce-8f7d-6b2eacfb4eb1","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1f41f5ac-5bb4-487e-becc-9e431dedc691","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f6689dee-0c31-479a-afd1-1fba88cd11cf","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d307f53a-8cf2-49d5-9bfe-dd17f176a299","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"0f98763d-a4d2-433d-9dce-d48a8f464928","attributes":{"name":"Column23618","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0595ef8a-6168-42ce-8f7d-6b2eacfb4eb1"},{"id":"1f41f5ac-5bb4-487e-becc-9e431dedc691"},{"id":"f6689dee-0c31-479a-afd1-1fba88cd11cf"},{"id":"d307f53a-8cf2-49d5-9bfe-dd17f176a299"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"9b711781-506c-41d4-8cd6-1acdeb0267be","attributes":{"name":"Column23600","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0595ef8a-6168-42ce-8f7d-6b2eacfb4eb1"},{"id":"1f41f5ac-5bb4-487e-becc-9e431dedc691"},{"id":"f6689dee-0c31-479a-afd1-1fba88cd11cf"},{"id":"d307f53a-8cf2-49d5-9bfe-dd17f176a299"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"9675902f-e54a-4206-996e-f0439e7efdce","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0595ef8a-6168-42ce-8f7d-6b2eacfb4eb1"},{"id":"f6689dee-0c31-479a-afd1-1fba88cd11cf"},{"id":"d307f53a-8cf2-49d5-9bfe-dd17f176a299"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1870,"step":5}},{"type":"object","name":"RadioButtonGroup","id":"7d6b9ce6-6881-42d8-87dc-585560bc5762","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0595ef8a-6168-42ce-8f7d-6b2eacfb4eb1"},{"type":"object","name":"ImportedStyleSheet","id":"b7e4aaef-29cb-4e46-bf9a-4ca8730a07d9","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"f6689dee-0c31-479a-afd1-1fba88cd11cf"},{"id":"d307f53a-8cf2-49d5-9bfe-dd17f176a299"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":1}}]}},{"type":"object","name":"panel.models.layout.Column","id":"5089e371-4871-45f9-a798-0ad1d5227e0f","attributes":{"name":"Column23615","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0595ef8a-6168-42ce-8f7d-6b2eacfb4eb1"},{"id":"1f41f5ac-5bb4-487e-becc-9e431dedc691"},{"id":"f6689de ...

# %% [markdown]
# CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='e09d09cd-491c-4802-8fba-42d611216691'>
#   <div id="fef70757-9a58-4d58-ae9c-1684489e75b8" data-root-id="e09d09cd-491c-4802-8fba-42d611216691" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e25e145d-5e77-48c1-840a-27dcb3080bbf":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"e09d09cd-491c-4802-8fba-42d611216691","attributes":{"name":"Row26575","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"0b9768a2-526c-4f53-8481-0a2b94eb72ec","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"93d4fb2b-b0b9-446c-a1d8-e3ae783995ff","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d3c1ce37-ab70-4c09-a0b8-dbf90803f0f2","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":
stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e7a048d-1037-47a1-8f96-c9584eb8a347"},{"id":"f1b18896-9c7f-402a-8283-cc192d359ea6"},{"id":"2d22edaa-8f5e-4a86-b2fe-2e8839b9e51c"},{"id":"1a89eae8-a52c-41a4-b6c4-bdb76266e6c0"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"4607ec45-fcfe-42ba-a889-94c31694758f","attributes":{"name":"Column39633","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e7a048d-1037-47a1-8f96-c9584eb8a347"},{"id":"f1b18896-9c7f-402a-8283-cc192d359ea6"},{"id":"2d22edaa-8f5e-4a86-b2fe-2e8839b9e51c"},{"id":"1a89eae8-a52c-41a4-b6c4-bdb76266e6c0"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"505862fd-0ded-4af9-813c-01d7dcac717f","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0e7a048d-1037-47a1-8f96-c9584eb8a347"},{"id":"2d22edaa-8f5e-4a86-b2fe-2e8839b9e51c"},{"id":"1a89eae8-a52c-41a4-b6c4-bdb76266e6c0"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1870,"step":5}}]}},{"type":"object","name":"Figure","id":"3e590ff6-fbb1-41f9-9c8c-86ce6f973498","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"8c1ced03-cf68-4aee-96e7-911407ebc66d","attributes":{"tags":[[["gdp_per_capita","gdp_per_capita",null]],[]],"start":-582.6574408595709,"end":6409.231849455279,"reset_start":-582.6574408595709,"reset_end":6409.231849455279}},"y_range":{"type":"object","name":"Range1d","id":"d06a82a1-b7fc-480e-9d34-383dac4bfe2f","attributes":{"tags":[[["co2","co2",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-52.946799999999996,"end":582.4148,"reset_start":-52.946799999999996,"reset_end":582.4148}},"x_scale":{"type":"object","name":"LinearScale","id":"07ddcd75-61f6-4e90-a71f-8abcfbf6d8a9"},"y_scale":{"type":"object","name":"LinearScale","id":"8b57a33c-ed7a-4c70-8d9a-84971304e708"},"title":{"type":"object","name":"Title","id":"5af67d2c-9c2b-4e45-b004-afe094756a7c","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"1b42f445-f0cf-40cc-b9e3-472ea92287c0","attributes":{"data_source":{"type":"object","n ...

# %% [markdown]
# Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='c8801867-c2d1-40a4-88cb-2daa35dfc644'>
#   <div id="e2df32b5-4cc5-41fc-8ac5-937fbc312d1a" data-root-id="c8801867-c2d1-40a4-88cb-2daa35dfc644" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9d3ba664-5358-474a-8ae8-e47165a3f1cc":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"c8801867-c2d1-40a4-88cb-2daa35dfc644","attributes":{"name":"Row48544","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"b9ef23f6-f166-4b1a-b946-cb60ed55017c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"2a6b6de5-9353-47d7-911b-d475a7654e3f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4624eb5c-9cc3-4bea-b22f-caf41deec026","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"85969030-1628-433f-ae75-f879583b2220","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"72a37a1c-70e5-4914-a627-2df579c9ba8f","attributes":{"name":"Column48541","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"b9ef23f6-f166-4b1a-b946-cb60ed55017c"},{"id":"2a6b6de5-9353-47d7-911b-d475a7654e3f"},{"id":"4624eb5c-9cc3-4bea-b22f-caf41deec026"},{"id":"85969030-1628-433f-ae75-f879583b2220"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7e228794-e510-4a59-9beb-f9bad2885237","attributes":{"name":"Column48524","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"b9ef23f6-f166-4b1a-b946-cb60ed55017c"},{"id":"2a6b6de5-9353-47d7-911b-d475a7654e3f"},{"id":"4624eb5c-9cc3-4bea-b22f-caf41deec026"},{"id":"85969030-1628-433f-ae75-f879583b2220"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"b50f3d63-9021-4336-95df-b89606e6e424","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"b9ef23f6-f166-4b1a-b946-cb60ed55017c"},{"id":"4624eb5c-9cc3-4bea-b22f-caf41deec026"},{"id":"85969030-1628-433f-ae75-f879583b2220"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1870,"step":5}},{"type":"object","name":"RadioButtonGroup","id":"f912931a-f78b-4e62-9b79-31c3e1d0d12f","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"b9ef23f6-f166-4b1a-b946-cb60ed55017c"},{"type":"object","name":"ImportedStyleSheet","id":"bad10062-17cf-4d6d-9d74-dc0a0ea26cc5","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"4624eb5c-9cc3-4bea-b22f-caf41deec026"},{"id":"85969030-1628-433f-ae75-f879583b2220"}],"margin":[5,10],"align":"start","labels":["coal_co2","oil_co2","gas_co2"],"active":0}}]}},{"type":"object","name":"Figure","id":"a1a964d8-9f35-4986-ae41-25ef46724def","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"08f6df37-e615-44d0-aecf-cf22de82f430","attributes":{"tags":[[["country","country",null]],[]],"factors":["Africa","Antarctica","Asia","Europe","North America","Oceania","South America"]}},"y_range":{"type":"object","name":"Range1d","id":"7b4b9d34-0a59-4788-b65 ...

# %% [markdown]
# Creating Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG('climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.servable();
